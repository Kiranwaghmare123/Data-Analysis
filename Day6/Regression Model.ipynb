# %%
#Simple Linear Regression
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Import dataset
dataset = pd.read_csv('Salary_Data.csv')
dataset
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
#Independent variable
X = dataset.iloc[:,:-1].values
#DEpendent variable
y = dataset.iloc[:,-1].values

# %%
#Splitting dataset into training anad testing
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=1)

# %%
#Linear Model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Prediction
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([75074.50510972, 91873.8056381 , 62008.38247653, 81607.56642631,
#        67608.14931932, 89073.92221671])

# %%
plt.scatter(X_train,y_train, color='red')
plt.plot(X_train, regressor.predict(X_train),color='blue')

# %%
#y=bx+a
b = regressor.coef_
b
# Out:
# array([9332.94473799])

# %%
a = regressor.intercept_
a
# Out:
# 25609.897998354834

# %%
y = bx + a
y = 9332.94*x + 25609.89

# %%
#Prediction

regressor.predict([[1]])
# Out:
# array([34942.84273635])

# %%
from sklearn import metrics
metrics.mean_squared_error(y_test, y_pred)
# Out:
# 51338023.49224838

# %%
metrics.r2_score(y_test,y_pred)
# Out:
# 0.7616681465472096

# %%
#Multilinear Regression Modl
dataset = pd.read_csv('50_Startups.csv')
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
dataset.shape
# Out:
# (50, 5)

# %%
dataset.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
#Independent variable
X = dataset.iloc[:,:-1].values
#Dependent variable
y = dataset.iloc[:,-1].values

# %%
X
# Out:
# array([[165349.2, 136897.8, 471784.1, 'New York'],
#        [162597.7, 151377.59, 443898.53, 'California'],
#        [153441.51, 101145.55, 407934.54, 'Florida'],
#        [144372.41, 118671.85, 383199.62, 'New York'],
#        [142107.34, 91391.77, 366168.42, 'Florida'],
#        [131876.9, 99814.71, 362861.36, 'New York'],
#        [134615.46, 147198.87, 127716.82, 'California'],
#        [130298.13, 145530.06, 323876.68, 'Florida'],
#        [120542.52, 148718.95, 311613.29, 'New York'],
#        [123334.88, 108679.17, 304981.62, 'California'],
#        [101913.08, 110594.11, 229160.95, 'Florida'],
#        [100671.96, 91790.61, 249744.55, 'California'],
#        [93863.75, 127320.38, 249839.44, 'Florida'],
#        [91992.39, 135495.07, 252664.93, 'California'],
#        [119943.24, 156547.42, 256512.92, 'Florida'],
#        [114523.61, 122616.84, 261776.23, 'New York'],
#        [78013.11, 121597.55, 264346.06, 'California'],
# ...

# %%
#Preprocessing
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
#Feature transformation: categorical data into numerical data
ct = ColumnTransformer(transformers=[
    ('encoders', OneHotEncoder(),[3])
],remainder='passthrough')

# %%
X = np.array(ct.fit_transform(X))

# %%
X
# Out:
# array([[0.0, 0.0, 1.0, 165349.2, 136897.8, 471784.1],
#        [1.0, 0.0, 0.0, 162597.7, 151377.59, 443898.53],
#        [0.0, 1.0, 0.0, 153441.51, 101145.55, 407934.54],
#        [0.0, 0.0, 1.0, 144372.41, 118671.85, 383199.62],
#        [0.0, 1.0, 0.0, 142107.34, 91391.77, 366168.42],
#        [0.0, 0.0, 1.0, 131876.9, 99814.71, 362861.36],
#        [1.0, 0.0, 0.0, 134615.46, 147198.87, 127716.82],
#        [0.0, 1.0, 0.0, 130298.13, 145530.06, 323876.68],
#        [0.0, 0.0, 1.0, 120542.52, 148718.95, 311613.29],
#        [1.0, 0.0, 0.0, 123334.88, 108679.17, 304981.62],
#        [0.0, 1.0, 0.0, 101913.08, 110594.11, 229160.95],
#        [1.0, 0.0, 0.0, 100671.96, 91790.61, 249744.55],
#        [0.0, 1.0, 0.0, 93863.75, 127320.38, 249839.44],
#        [1.0, 0.0, 0.0, 91992.39, 135495.07, 252664.93],
#        [0.0, 1.0, 0.0, 119943.24, 156547.42, 256512.92],
#        [0.0, 0.0, 1.0, 114523.61, 122616.84, 261776.23],
#        [1.0, 0.0, 0.0, 78013.11, 121597.55, 264346.06],
# ...

# %%
#Splitting of data
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.2,random_state=42)

# %%
#Linear Model
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(dataset['R&D Spend'],dataset['Profit'])
plt.plot(dataset['R&D Spend'],dataset['Profit'], color='r')

# %%
# predictions
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([120254.01027896,  77303.26055777,  93917.01153772,  47654.10539606,
#        139698.04509389,  58109.23897702, 103288.78572423,  90496.06208822,
#         87115.09694367, 119319.82435141, 127178.00679792, 180474.12695425,
#         87925.77784206, 163442.01296997, 192214.17287752, 151300.53920749,
#         71228.9217705 ,  48343.43002778,  27707.84938854, 159945.20034988,
#        154436.31545314, 110372.72749751, 125002.64102231,  74518.55743873,
#        100563.75278722, 211853.69492608,  45737.45128466, 125126.07058218,
#         95159.58980847, 183073.55227775, 105286.84678276, 134478.31852281,
#         67042.01647637, 188780.08382512, 124589.46308654, 190846.25820678,
#         61502.1418059 , 102181.33117592, 109239.29504836,  63093.00948991])

# %%
from sklearn.metrics import mean_squared_error, r2_score
mean_squared_error(y_test,y_pred)
# Out:
# 189852849.35413727

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8807368498661143

# %%
diff = pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
diff
# Out:
#        Actual      Predicted
# 0   134307.35  120254.010279
# 1    81005.76   77303.260558
# 2    99937.59   93917.011538
# 3    64926.08   47654.105396
# 4   125370.37  139698.045094
# 5    35673.41   58109.238977
# 6   105733.54  103288.785724
# 7   107404.34   90496.062088
# 8    97427.84   87115.096944
# 9   122776.86  119319.824351
# 10  141585.52  127178.006798
# 11  166187.94  180474.126954
# 12   89949.14   87925.777842
# 13  152211.77  163442.012970
# 14  182901.99  192214.172878
# 15  156122.51  151300.539207
# 16   77798.83   71228.921771
# 17   49490.75   48343.430028
# 18   42559.73   27707.849389
# 19  129917.04  159945.200350
# 20  149759.96  154436.315453
# 21  126992.93  110372.727498
# 22  108552.04  125002.641022
# 23   96712.80   74518.557439
# 24   97483.56  100563.752787
# 25  192261.83  211853.694926
# 26   65200.33   45737.451285
# 27  105008.31  125126.070582
# 28   96778.92   95159.589808
# 29  156991.12  183073.552278
# 30  101004.64  105286.846783
# ...

# %%
#Ploynomial Regression
dataset = pd.read_csv('hw.csv')
dataset
# Out:
#     Age  Height
# 0    10     138
# 1    11     138
# 2    12     138
# 3    13     139
# 4    14     139
# ..  ...     ...
# 66   76     204
# 67   77     205
# 68   78     206
# 69   79     207
# 70   80     208
#
# [71 rows x 2 columns]

# %%
dataset.describe()
# Out:
#              Age      Height
# count  71.000000   71.000000
# mean   45.000000  160.873239
# std    20.639767   20.842902
# min    10.000000  138.000000
# 25%    27.500000  143.500000
# 50%    45.000000  155.000000
# 75%    62.500000  171.500000
# max    80.000000  208.000000

# %%
import seaborn as sns
#Visualize the dataset
sns.pairplot(dataset)
plt.show()

# %%
X = dataset.iloc[:,:-1].values
y = dataset.iloc[:,-1].values

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=0)

# %%
lm = LinearRegression()
lm.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(X_test)
y_pred
# Out:
# array([152.2637827 , 153.220389  , 173.3091214 , 148.43735748,
#        156.09020791, 176.17894031, 134.08826291, 183.83179074,
#        159.91663313, 194.35446009, 180.96197183, 154.17699531,
#        157.04681422, 167.56948357, 158.96002683])

# %%
diff = pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
diff
# Out:
#     Actual   Predicted
# 0      148  152.263783
# 1      148  153.220389
# 2      167  173.309121
# 3      146  148.437357
# 4      150  156.090208
# 5      170  176.178940
# 6      140  134.088263
# 7      185  183.831791
# 8      153  159.916633
# 9      208  194.354460
# 10     178  180.961972
# 11     149  154.176995
# 12     150  157.046814
# 13     162  167.569484
# 14     152  158.960027

# %%
plt.scatter(X,y, color='red')
plt.plot(X,lm.predict(X), color='blue')

# %%
#Polynomial Model
from sklearn.preprocessing import PolynomialFeatures
pm = PolynomialFeatures(degree = 8)
X_poly = pm.fit_transform(X)
lml = LinearRegression()
lml.fit(X_poly,y)
# Out:
# LinearRegression()

# %%
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape((len(X_grid),1))
plt.scatter(X,y, color='red')
plt.plot(X_grid, lml.predict(pm.fit_transform(X_grid)), color='blue')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9192\1209088108.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X),max(X),0.1)
